# %% [markdown]
# # Fabrication d'une cellule galvanique

# %%
#Pb*Zn

# %%
from chemlib import Galvanic_Cell
g=Galvanic_Cell("Pb","Zn")
g.properties
# Out:
# {'Cell': 'Zn | Zn2+ || Pb2+ | Pb',
#  'Anode': 'Zn',
#  'Cathode': 'Pb',
#  'Cell Potential': 0.63}

# %%
g.draw()
g.diagram.save("PbZn.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
image = img.imread('PbZn.png')
plt.imshow(image)
plt.show()

# %%
#Cu*Zn

# %%
from chemlib import Galvanic_Cell
g=Galvanic_Cell("Cu","Zn")
g.properties
# Out:
# {'Cell': 'Zn | Zn2+ || Cu2+ | Cu',
#  'Anode': 'Zn',
#  'Cathode': 'Cu',
#  'Cell Potential': 1.1}

# %%
g.draw()
g.diagram.save("CuZn.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
image = img.imread('CuZn.png')
plt.imshow(image)
plt.show()
